# %% [markdown]
# Aquí voy a hablar de mis tres hipótesis, las gráficas y las conclusiones.

# %% [markdown]
# Mi primera hipótesis, era que los ataques de tiburones en Australia serían más mortales. La gráfica resultante ha sido la siguiente.

# %% [markdown]
# ![grafico1.png](attachment:grafico1.png)

# %%
Conclusión: Se puede apreciar como efectivamente los ataques son más mortales porcentualmente en Australia, aunque seguido muy de cerca de Sudáfrica.

# %% [markdown]
# Mi segunda hipótesis, decía que los ataques de tiburón blanco habían subido menos con los años que los ataques de otros en Estados Unidos.

# %% [markdown]
# ![grafico2.png](attachment:grafico2.png)

# %% [markdown]
# Esta gráfica es dificil de leer y tampoco dice mucho acerca de lo que queremos saber, por lo tanto he realizado un subplot partiendo ésta en tres:

# %% [markdown]
# ![grafico3.png](attachment:grafico3.png)

# %% [markdown]
# Esta gráfica lo que indica es que nuestra hipótesis está mal, dado que en términos absolutos los ataques de tiburones blancos son los que más han crecido. De todos modos, cabe explicar que los crecimientos en ataques con los años, se deben a que antes no se guardaba registro de la mayoría de estos ataques. Probablemente de ataques de tiburones blancos menos, dado que ocurrían en aguas abiertas.

# %%
Mi tercera hipótesis decía que porcentualmente en sudáfica es dónde más ataques de tiburón blanco hay. He creado las gráficaas en términos porcentuales y absolutos.

# %% [markdown]
# ![grafico5.png](attachment:grafico5.png)

# %% [markdown]
# ![grafico4.png](attachment:grafico4.png)

# %% [markdown]
# Estas dos gráficas nos permiten ver como en términos absolutos, es en Estados Unidos dónde hay más ataques de tiburón blanco, pero es que en general es dónde más ataques de tiburón se registran. En cambio en términos poorcentuales, es en sudáfrica dónde más ataques de tiburón blanco se registran.

# %%
Mi cuarta hipotesis es que los ataques de tiburón blanco son los más letales en estos paises. Como antes lo vamos a ver en términos absolutos y porcentuales.

# %% [markdown]
# ![grafico6.png](attachment:grafico6.png)

# %% [markdown]
# ![grafico7.png](attachment:grafico7.png)

# %% [markdown]
# De nuevo en términos absolutos el tiburón blanco es el más letal, pero también es del cual más ataques hay registrados. En cambio si lo vemos en términos porcentuales todos los tiburones son similarmente letales, siendo el tiburón blanco el que más.
